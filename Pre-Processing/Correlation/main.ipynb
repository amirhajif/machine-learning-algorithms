# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# this data set contains 146 columns - features

# %%
data=pd.read_csv(" .csv")
data.head()
# Out:
#                          Team  Games Win-Loss  Off Rank  Off Plays  Off Yards  \
# 0   Air Force (Mountain West)     13     11-2        51        881       5483
# 1                 Akron (MAC)     12     0-12       130        725       2918
# 2               Alabama (SEC)     13     11-2         6        842       6640
# 3  Appalachian St. (Sun Belt)     14     13-1        39        969       6064
# 4            Arizona (Pac-12)     12      4-8        30        873       5281
#
#    Off Yards/Play  Off TDs  Off Yards per Game  Def Rank  ...  \
# 0            6.22       55               421.8        17  ...
# 1            4.02       14               243.2        83  ...
# 2            7.89       76               510.8        20  ...
# 3            6.26       65               433.1        26  ...
# 4            6.05       42               440.1       120  ...
#
#    Average Time of Possession per Game  Turnover Rank  Fumbles Recovered  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Columns: 146 entries, Team to Avg Turnover Margin per Game
# dtypes: float64(29), int64(113), object(4)
# memory usage: 148.4+ KB

# %% [markdown]
# how to find columns with specific Type

# %%
object_columns=data.select_dtypes(include=['object'])
object_columns.columns
# Out:
# Index(['Team', 'Win-Loss', 'Time of Possession',
#        'Average Time of Possession per Game'],
#       dtype='object')

# %% [markdown]
# make separate a column data into 2 columns

# %%
win_loss_data=data['Win-Loss'].str.split("-",expand=True)
win_loss_data
# Out:
#       0   1
# 0    11   2
# 1     0  12
# 2    11   2
# 3    13   1
# 4     4   8
# ..   ..  ..
# 125   5   7
# 126   9   4
# 127   7   6
# 128  10   4
# 129   8   5
#
# [130 rows x 2 columns]

# %%
data['Win']=win_loss_data[0]
data['Loss']=win_loss_data[1]
data
# Out:
#                            Team  Games Win-Loss  Off Rank  Off Plays  \
# 0     Air Force (Mountain West)     13     11-2        51        881
# 1                   Akron (MAC)     12     0-12       130        725
# 2                 Alabama (SEC)     13     11-2         6        842
# 3    Appalachian St. (Sun Belt)     14     13-1        39        969
# 4              Arizona (Pac-12)     12      4-8        30        873
# ..                          ...    ...      ...       ...        ...
# 125      West Virginia (Big 12)     12      5-7       119        788
# 126         Western Ky. (C-USA)     13      9-4        84        900
# 127         Western Mich. (MAC)     13      7-6        25        916
# 128         Wisconsin (Big Ten)     14     10-4        38        963
# 129     Wyoming (Mountain West)     13      8-5       106        831
#
#      Off Yards  Off Yards/Play  Off TDs  Off Yards per Game  Def Rank  ...  \
# ...

# %% [markdown]
# drop last column

# %%
data=data.drop('Win-Loss',axis=1)
data
# Out:
#                            Team  Games  Off Rank  Off Plays  Off Yards  \
# 0     Air Force (Mountain West)     13        51        881       5483
# 1                   Akron (MAC)     12       130        725       2918
# 2                 Alabama (SEC)     13         6        842       6640
# 3    Appalachian St. (Sun Belt)     14        39        969       6064
# 4              Arizona (Pac-12)     12        30        873       5281
# ..                          ...    ...       ...        ...        ...
# 125      West Virginia (Big 12)     12       119        788       3863
# 126         Western Ky. (C-USA)     13        84        900       5041
# 127         Western Mich. (MAC)     13        25        916       5794
# 128         Wisconsin (Big Ten)     14        38        963       6065
# 129     Wyoming (Mountain West)     13       106        831       4562
#
#      Off Yards/Play  Off TDs  Off Yards per Game  Def Rank  Def Plays  ...  \
# ...

# %%
data['Win']=data['Win'].apply(pd.to_numeric)
data['Win']
# Out:
# 0      11
# 1       0
# 2      11
# 3      13
# 4       4
#        ..
# 125     5
# 126     9
# 127     7
# 128    10
# 129     8
# Name: Win, Length: 130, dtype: int64

# %%
data['Loss']=data['Loss'].apply(pd.to_numeric)
data['Loss']
# Out:
# 0       2
# 1      12
# 2       2
# 3       1
# 4       8
#        ..
# 125     7
# 126     4
# 127     6
# 128     4
# 129     5
# Name: Loss, Length: 130, dtype: int64

# %%
datas_corr=data.corr()
datas_corr
# Out:
# /var/folders/ym/gjrx4mts0h3g9f_769wf3w8h0000gn/T/ipykernel_3757/405452368.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datas_corr=data.corr()
#                                  Games  Off Rank  Off Plays  Off Yards  \
# Games                         1.000000 -0.428834   0.723447   0.718944
# Off Rank                     -0.428834  1.000000  -0.690523  -0.905437
# Off Plays                     0.723447 -0.690523   1.000000   0.816111
# Off Yards                     0.718944 -0.905437   0.816111   1.000000
# Off Yards/Play                0.546835 -0.873236   0.515047   0.911832
# ...                                ...       ...        ...        ...
# Turnovers Lost               -0.098361  0.172833  -0.085804  -0.190193
# Turnover Margin               0.374522 -0.302050   0.363652   0.382880
# ...

# %%
datas_corr.loc[['Win']]
# Out:
#         Games  Off Rank  Off Plays  Off Yards  Off Yards/Play   Off TDs  \
# Win  0.867916  -0.54751   0.715855   0.773413        0.651545  0.774386
#
#      Off Yards per Game  Def Rank  Def Plays  Yards Allowed  ...  \
# Win            0.613811 -0.649593    0.40999      -0.367941  ...
#
#      Fumbles Recovered  Opponents Intercepted  Turnovers Gain  Fumbles Lost  \
# Win           0.230569               0.569342        0.569814     -0.015865
#
#      Interceptions Thrown.y  Turnovers Lost  Turnover Margin  \
# Win               -0.370948       -0.305809          0.54536
#
#      Avg Turnover Margin per Game  Win      Loss
# Win                      0.544279  1.0 -0.988655
#
# [1 rows x 144 columns]

# %%
datas_corr.loc[['Loss']]
# Out:
#          Games  Off Rank  Off Plays  Off Yards  Off Yards/Play   Off TDs  \
# Loss -0.783464  0.555317  -0.676846  -0.750219       -0.649794 -0.759559
#
#       Off Yards per Game  Def Rank  Def Plays  Yards Allowed  ...  \
# Loss           -0.622071  0.647073  -0.352309       0.406359  ...
#
#       Fumbles Recovered  Opponents Intercepted  Turnovers Gain  Fumbles Lost  \
# Loss           -0.22846              -0.560768       -0.562061      0.044502
#
#       Interceptions Thrown.y  Turnovers Lost  Turnover Margin  \
# Loss                0.406763        0.352856        -0.569051
#
#       Avg Turnover Margin per Game       Win  Loss
# Loss                     -0.568118 -0.988655   1.0
#
# [1 rows x 144 columns]

# %% [markdown]
# ## Kendal

# %%
datas_corr_kendal=data.corr(method='kendall')
datas_corr_kendal
# Out:
# /var/folders/ym/gjrx4mts0h3g9f_769wf3w8h0000gn/T/ipykernel_3757/1634076742.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datas_corr_kendal=data.corr(method='kendall')
#                                  Games  Off Rank  Off Plays  Off Yards  \
# Games                         1.000000 -0.333696   0.575926   0.569697
# Off Rank                     -0.333696  1.000000  -0.506877  -0.813145
# Off Plays                     0.575926 -0.506877   1.000000   0.611781
# Off Yards                     0.569697 -0.813145   0.611781   1.000000
# Off Yards/Play                0.404334 -0.726481   0.333293   0.723297
# ...                                ...       ...        ...        ...
# Turnovers Lost               -0.133555  0.151544  -0.076209  -0.151430
# ...

# %%
datas_corr_kendal['Win']
# Out:
# Games                           0.786640
# Off Rank                       -0.381265
# Off Plays                       0.521522
# Off Yards                       0.565604
# Off Yards/Play                  0.434372
#                                   ...
# Turnovers Lost                 -0.223796
# Turnover Margin                 0.374587
# Avg Turnover Margin per Game    0.374600
# Win                             1.000000
# Loss                           -0.970291
# Name: Win, Length: 144, dtype: float64

# %% [markdown]
# ## Plot HeatMap for Corr

# %%
plt.Figure(figsize=(20,12))
sns.heatmap(datas_corr,cmap="YlGnBu",annot=True)
# Out:
# <Axes: >

# %%
plt.Figure(figsize=(20,12))
sns.heatmap(datas_corr[datas_corr['Win']>0.7],cmap="YlGnBu",annot=True)
# Out:
# <Axes: >
